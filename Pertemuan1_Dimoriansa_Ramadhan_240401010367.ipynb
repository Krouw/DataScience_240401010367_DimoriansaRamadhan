# %% [markdown]
# <a href="https://colab.research.google.com/github/Krouw/data-science-2026/blob/main/Pertemuan1_Dimoriansa_Ramadhan_240401010367.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama  : Dimoriansa Ramadhan
#
# NIM   : 240401010367
#
# Kelas : IF-403

# %%
#Output Sederhana
print("Hello UNSIA")
# Out:
# Hello UNSIA

# %%
#Variabel dan Tipe Data
nama = "Dimoriansa Ramadhan" #string
prodi = "Teknik Informatika" #string
angkatan = 2025 #numerik
print(nama)
print(prodi)
print(angkatan)
print(f"Halo nama saya {nama} dari prodi {prodi} angkatan {angkatan}")
# Out:
# Dimoriansa Ramadhan
# Teknik Informatika
# 2025
# Halo nama saya Dimoriansa Ramadhan dari prodi Teknik Informatika angkatan 2025

# %%
#List
tools = ["Python", "Google colab", "Jupiter notebook", "Github"]

#Perulangan
for i in tools :
  print(i)
# Out:
# Python
# Google colab
# Jupiter notebook
# Github

# %%
#Fungsi
def perkenalan(nama, prodi, angkatan) :
  return print(f"Halo nama saya {nama} dari prodi {prodi} angkatan {angkatan}")

perkenalan("Dimoriansa Ramadhan", "Informatika", 2025)
# Out:
# Halo nama saya Dimoriansa Ramadhan dari prodi Informatika angkatan 2025

# %% [markdown]
# Kesimpulan singkat :
#
# Pada pertemuan ke 1 ini, saya dapat mempelajari tentang dasar-dasar pemrograman Python, seperti output sederhana, variabel & tipe data, list, perulangan, serta fungsi. yang dimana tersebut merupakan hal yang belum pernah saya alami. ada rasa excited disana.
#
# Temuan utamanya : Python bahasa pemrograman yang hits & banyak digunakan di dunia, serta cukup mudah dipahami karena sintaksnya sederhana dan dapat digunakan untuk menampilkan data maupun melakukan perulangan secara otomatis. Dari kode yang dibuat juga terlihat bahwa fungsi dapat membantu agar program lebih rapi dan dapat digunakan kembali.
#
# Keterbatasan pada program ini adalah masih sangat sederhana karena belum menggunakan input dari pengguna atau pengolahan data yang lebih kompleks, dan saya menantikan untuk program pelajaran apa yang akan dilakukan selanjutnya.
