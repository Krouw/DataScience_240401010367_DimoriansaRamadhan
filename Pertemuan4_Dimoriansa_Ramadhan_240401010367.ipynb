# %% [markdown]
# <a href="https://colab.research.google.com/github/Krouw/data-science-2026/blob/main/Pertemuan4_Dimoriansa_Ramadhan_240401010367.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama  : Dimoriansa Ramadhan
#
# NIM   : 240401010367
#
# Kelas : IF-403

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns

# %%
#Langkah 1: Memuat dataset iris menggunakan seaborn.load_dataset(). Tampilkan shape, dtypes, head(), dan .describe().

print("\n==== Load & Inspect Dataset ====\n")

df = sns.load_dataset('iris')

print('Shape:', df.shape)
print('\n Tipe Data:')
print(df.dtypes)

print('\n 5 Data Teratas:')
print(df.head())

print('\n Statistika Deskriptif:')
print(df.describe().round(3))
# Out:
# ==== Load & Inspect Dataset ====
#
# Shape: (150, 5)
#
#  Tipe Data:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
#
#  5 Data Teratas:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
#  Statistika Deskriptif:
#        sepal_length  sepal_width  petal_length  petal_width
# count       150.000      150.000       150.000      150.000
# mean          5.843        3.057         3.758        1.199
# std           0.828        0.436         1.765        0.762
# min           4.300        2.000         1.000        0.100
# 25%           5.100        2.800         1.600        0.300
# 50%           5.800        3.000         4.350        1.300
# 75%           6.400        3.300         5.100        1.800
# max           7.900        4.400         6.900        2.500

# %%
#Langkah 2: Menghitung mean, median, std, varians, skewness, kurtosis untuk setiap kolom numerik.

print("\n==== Statistik Deskriptif Lengkap ====")

for col_name in df.select_dtypes(include='number').columns:
    col = df[col_name]
    print(f'\n=== {col_name} ===')
    print(f'  Mean     : {col.mean():.3f}')
    print(f'  Median   : {col.median():.3f}')
    print(f'  Std Dev  : {col.std():.3f}')
    print(f'  Skewness : {col.skew():.3f}')
# Out:
# ==== Statistik Deskriptif Lengkap ====
#
# === sepal_length ===
#   Mean     : 5.843
#   Median   : 5.800
#   Std Dev  : 0.828
#   Skewness : 0.315
#
# === sepal_width ===
#   Mean     : 3.057
#   Median   : 3.000
#   Std Dev  : 0.436
#   Skewness : 0.319
#
# === petal_length ===
#   Mean     : 3.758
#   Median   : 4.350
#   Std Dev  : 1.765
#   Skewness : -0.275
#
# === petal_width ===
#   Mean     : 1.199
#   Median   : 1.300
#   Std Dev  : 0.762
#   Skewness : -0.103

# %%
#Langkah 3: Membuat histogram + KDE untuk sepal_length. Tambahkan garis mean dan median. Identifikasi jenis distribusinya.
import matplotlib.pyplot as plt
import seaborn as sns
print("\n==== Analisis Distribusi (Histogram + KDE) ====\n")

fig, ax = plt.subplots(figsize=(8, 4))

sns.histplot(df['sepal_length'], kde=True,
             color='#028090', bins=20, ax=ax)

ax.axvline(df['sepal_length'].mean(), color='red',
           linestyle='--', label=f"Mean={df['sepal_length'].mean():.2f}")

ax.axvline(df['sepal_length'].median(), color='orange',
           linestyle='--', label=f"Median={df['sepal_length'].median():.2f}")

ax.set_title('Distribusi Sepal Length')
ax.legend()

plt.show()
# Out:
# ==== Analisis Distribusi (Histogram + KDE) ====

# %% [markdown]
# Distribusi sepal length termasuk hampir normal, akan tetapi cenderung sedikit miring ke kanan.

# %%
#Langkah 4: Membuat boxplot petal_length per spesies. Identifikasi spesies dengan nilai terbesar, terkecil, dan paling tersebar.

print("\n==== Boxplot per Spesies ====\n")

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.boxplot(
  data=df,
  x='species',
  y='petal_length',
  hue='species',
  palette='Set2',
  ax=axes[0]
)

axes[0].set_title('Boxplot Petal Length')

sns.violinplot(
  data=df,
  x='species',
  y='petal_length',
  hue='species',
  palette='Set2',
  inner='box',
  ax=axes[1]
)

axes[1].set_title('Violin Plot Petal Length')

plt.tight_layout()
plt.show()
# Out:
# ==== Boxplot per Spesies ====

# %% [markdown]
# Urutan spesies dari **terbesar hingga terkecil**, *virginica* - *versicolor* - *setosa*.
#
# begitu juga dengan spesies yang **paling tersebar** ialah *virginica*.

# %%
#Langkah 5: Menhitung matriks korelasi. Identifikasi pasangan kolom dengan korelasi tertinggi dan terendah.

print("\n==== Matriks Korelasi Pearson ====\n")

corr = df.drop('species', axis=1).corr(method='pearson')
print(corr.round(3))
import numpy as np
mask = np.triu(np.ones(corr.shape, dtype=bool))
corr_masked = corr.where(~mask)
max_pair = corr_masked.stack().idxmax()
min_pair = corr_masked.stack().idxmin()

print('\n Hasilnya sebagai berikut :')
print(f'Korelasi tertinggi: {max_pair} = {corr.loc[max_pair]:.3f}')
print(f'Korelasi terendah: {min_pair} = {corr.loc[min_pair]:.3f}')
# Out:
# ==== Matriks Korelasi Pearson ====
#
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length         1.000       -0.118         0.872        0.818
# sepal_width         -0.118        1.000        -0.428       -0.366
# petal_length         0.872       -0.428         1.000        0.963
# petal_width          0.818       -0.366         0.963        1.000
#
#  Hasilnya sebagai berikut :
# Korelasi tertinggi: ('petal_width', 'petal_length') = 0.963
# Korelasi terendah: ('petal_length', 'sepal_width') = -0.428

# %% [markdown]
# Pada data diatas, sudah terdapat **Korelasi Tertinggi & Terendah**.

# %%
#Langkah 6: Membuat scatter plot pasangan paling berkorelasi + heatmap lengkap. Sertakan narasi interpretasi dalam Markdown.

print("\n==== Scatter Plot & Heatmap ====\n")

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
sns.scatterplot(data=df, x='petal_length', y='petal_width',
hue='species', palette='Set2', ax=axes[0])
sns.regplot(data=df, x='petal_length', y='petal_width',
scatter=False, color='gray', ax=axes[0])
axes[0].set_title('Scatter: Petal Length vs Petal Width')
sns.heatmap(corr, annot=True, fmt='.2f', cmap='RdBu_r',
vmin=-1, vmax=1, square=True, ax=axes[1])
axes[1].set_title('Heatmap Korelasi')
plt.tight_layout(); plt.show()
# Out:
# ==== Scatter Plot & Heatmap ====

# %% [markdown]
# Spesies *Virginica* punya dimensi petal terbesar, sementara *Versicolor* berada di tengah, lalu di akhir ada *Setosa*.
#
# Ukuran panjang dan lebar petal punya korelasi paling kuat (0.96). Bila satu naik, yang lain pasti naik.

# %% [markdown]
# Kesimpulan singkat :
#
# Pada pertemuan ke 4 ini, saya mempelajari analisis statistik dan visualisasi data menggunakan Pandas, Seaborn, dan Matplotlib pada dataset Iris.
#
# Beberapa hal yang dipelajari yaitu menghitung statistik deskriptif seperti mean, median, standar deviasi, skewness, membuat histogram, boxplot, violin plot, scatter plot, heatmap, serta mencari korelasi antar variabel.
#
# Temuan utamanya : petal_length dan petal_width memiliki korelasi paling tinggi, sedangkan setiap spesies iris memiliki karakteristik ukuran bunga yang berbeda. Visualisasi juga membantu memahami distribusi data dan penyebaran tiap spesies dengan lebih jelas.
#
# Keterbatasan pada praktikum ini adalah analisis masih sebatas eksplorasi data dan belum masuk ke tahap prediksi atau klasifikasi.
